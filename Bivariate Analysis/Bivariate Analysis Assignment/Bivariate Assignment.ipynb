# %%
import pandas as pd
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
# sl_no             215 non-null int64
# gender            215 non-null object
# ssc_p             215 non-null float64
# ssc_b             215 non-null object
# hsc_p             215 non-null float64
# hsc_b             215 non-null object
# hsc_s             215 non-null object
# degree_p          215 non-null float64
# degree_t          215 non-null object
# workex            215 non-null object
# etest_p           215 non-null float64
# specialisation    215 non-null object
# mba_p             215 non-null float64
# status            215 non-null object
# salary            148 non-null float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# # 1)Replace the NaN values with correct value. And justify why you have chosen the same.

# %%
# Ans: Replace the NaN values with 0, Because in this case, missing salary means the person is not placed, so salary = 0

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# # 2)How many of them are not placed?

# %%
# Ans : not_placed_count = 67

# %%
not_placed_count = dataset['status'].value_counts()['Not Placed']

print("not Placed = ",not_placed_count)
# Out:
# not Placed =  67

# %%
dataset["salary"].fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
def quanQual(dataset):
        quan=[]
        qual=[]
        for columnName in dataset.columns:
            #print(columnName)
            if(dataset[columnName].dtype=='O'):
                #print("qual")
                qual.append(columnName)
            else:
                #print("quan")
                quan.append(columnName)
        return quan,qual

# %%
quan,qual=quanQual(dataset)

# %%
dataset[quan]
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0
# 3        4  56.00  52.00     52.00     66.0  59.43       0.0
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0
# 214    215  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 7 columns]

# %%
import numpy as np
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan,strategy="mean")
dataset[quan] = imputer.fit_transform(dataset[quan])

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 211  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 212  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 213  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 214  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset.to_csv("Preplacement.csv",index=False)

# %% [markdown]
# # Central Tendency

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
def freqTable(columnName,dataset):
    freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative_Frequency","CumSum"])
    freqTable["Unique_Values"]=dataset[columnName].value_counts().index
    freqTable["Frequency"]=dataset[columnName].value_counts().values
    freqTable["Relative_Frequency"]=freqTable["Frequency"] / freqTable["Frequency"].sum()
    freqTable["CumSum"]=freqTable["Relative_Frequency"].cumsum()
    return freqTable

# %%
freqTable("ssc_p",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency    CumSum
# 0            62.00         11            0.051163  0.051163
# 1            63.00         10            0.046512  0.097674
# 2            67.00          9            0.041860  0.139535
# 3            52.00          9            0.041860  0.181395
# 4            73.00          9            0.041860  0.223256
# ..             ...        ...                 ...       ...
# 98           80.60          1            0.004651  0.981395
# 99           65.20          1            0.004651  0.986047
# 100          80.40          1            0.004651  0.990698
# 101          59.96          1            0.004651  0.995349
# 102          78.50          1            0.004651  1.000000
#
# [103 rows x 4 columns]

# %%
def Univariate(dataset,Quan):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR",
                                    "1.5rule","Lesser","Greater","Min","Max","kurtosis","skew","Variance",
                                    "StandardD"],columns=Quan)
    for columnName in Quan:
        descriptive[columnName]["Mean"]=dataset[columnName].mean()
        descriptive[columnName]["Median"]=dataset[columnName].median()
        descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
        descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Min"]=dataset[columnName].min()
        descriptive[columnName]["Max"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
        descriptive[columnName]["skew"]=dataset[columnName].skew()
        descriptive[columnName]["Variance"]=dataset[columnName].var()
        descriptive[columnName]["StandardD"]=dataset[columnName].std()        
    return descriptive

# %%
Univariate(dataset,quan)
# Out:
#              sl_no     ssc_p     hsc_p   degree_p   etest_p     mba_p  \
# Mean           108   67.3034   66.3332    66.3702   72.1006   62.2782
# Median         108        67        65         66        71        62
# Mode             1        62        63         65        60      56.7
# Q1:25%        54.5      60.6      60.9         61        60    57.945
# Q2:50%         108        67        65         66        71        62
# Q3:75%       161.5      75.7        73         72      83.5    66.255
# 99%         212.86        87     91.86      83.86        97   76.1142
# Q4:100%        215      89.4      97.7         91        98     77.89
# IQR            107      15.1      12.1         11      23.5      8.31
# 1.5rule      160.5     22.65     18.15       16.5     35.25    12.465
# Lesser        -106     37.95     42.75       44.5     24.75     45.48
# Greater        322     98.35     91.15       88.5    118.75     78.72
# ...

# %% [markdown]
# # 3)Find the reason for non placement from the dataset?

# %%
not_placed = dataset[dataset['status'] == 'Not Placed']
not_placed
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3      4.0      M   56.0  Central   52.0  Central   Science     52.00
# 5      6.0      M   55.0   Others   49.8   Others   Science     67.25
# 6      7.0      F   46.0   Others   49.2   Others  Commerce     79.00
# 9     10.0      M   58.0  Central   70.0  Central  Commerce     61.00
# 12    13.0      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198  199.0      F   67.0  Central   70.0  Central  Commerce     65.00
# 201  202.0      M   54.2  Central   63.0   Others   Science     58.00
# 206  207.0      M   41.0  Central   42.0  Central   Science     60.00
# 208  209.0      F   43.0  Central   60.0   Others   Science     65.00
# 214  215.0      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
# Compare by Univariate Analysis (QUAN)
dataset.groupby('status')[quan].mean()
# Out:
#                  sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# status
# Not Placed  110.477612  57.544030  58.395522  61.134179  69.587910  61.612836
# Placed      106.878378  71.721486  69.926554  68.740541  73.238041  62.579392
#
#                    salary
# status
# Not Placed       0.000000
# Placed      288655.405405

# %%
# A slight difference in ssc_p and hsc_p

# %%
# Compare by Univariate Analysis (QUAL)
for col in qual:
    print("\n", col)
    print(pd.crosstab(dataset[col], dataset['status']))
# Out:
#  gender
# status  Not Placed  Placed
# gender
# F               28      48
# M               39     100
#
#  ssc_b
# status   Not Placed  Placed
# ssc_b
# Central          38      78
# Others           29      70
#
#  hsc_b
# status   Not Placed  Placed
# hsc_b
# Central          27      57
# Others           40      91
#
#  hsc_s
# status    Not Placed  Placed
# hsc_s
# Arts               5       6
# Commerce          34      79
# Science           28      63
#
#  degree_t
# status     Not Placed  Placed
# degree_t
# Comm&Mgmt          43     102
# Others              6       5
# Sci&Tech           18      41
#
#  workex
# status  Not Placed  Placed
# workex
# No              57      84
# Yes             10      64
#
#  specialisation
# status          Not Placed  Placed
# specialisation
# Mkt&Fin                 25      95
# Mkt&HR                  42      53
#
#  status
# status      Not Placed  Placed
# status
# Not Placed          67       0
# Placed               0     148

# %%
# non has significant impact, having more workex has more chance of placed and similarly for Mkt&Fin specialisation

# %% [markdown]
# # 4)What kind of relation between salary and mba_p

# %%
dataset.cov()
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -58.106028     -40.413645
# ssc_p       -52.641355     117.228377      60.348373      42.897137
# hsc_p       -58.106028      60.348373     118.755706      34.819820
# degree_p    -40.413645      42.897137      34.819820      54.151103
# etest_p      52.556168      37.659225      35.461678      21.929469
# mba_p         8.102336      24.535952      22.555846      17.272020
# salary    24490.654206  901754.893936  763359.777657  465131.504238
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  2.449065e+04
# ssc_p         37.659225      24.535952  9.017549e+05
# hsc_p         35.461678      22.555846  7.633598e+05
# degree_p      21.929469      17.272020  4.651315e+05
# etest_p      176.251018      16.886973  3.842344e+05
# mba_p         16.886973      34.028376  1.262455e+05
# ...

# %%
#covariance between mba_p and salary is positive(1.262455e+05)-higher MBA % tends to be associated with higher salary.

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
#corelation between mba_p and salary is weak positive(0.139)-MBA % has very low relation with salary

# %% [markdown]
# # 5)Which specialization is getting minimum salary?

# %%
dataset[dataset['status']=='Placed'].groupby('specialisation')['salary'].min()
# Out:
# specialisation
# Mkt&Fin    200000.0
# Mkt&HR     200000.0
# Name: salary, dtype: float64

# %%
#this includes only Placed dataset
#Mkt&Fin    200000.0
#Mkt&HR     200000.0

# %% [markdown]
# # 6)How many of them getting above 500000 salary?

# %%
count = (dataset['salary'] > 500000).sum()

print('above 500000 salary =',count)
# Out:
# above 500000 salary = 3

# %% [markdown]
# # 7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats
f_stat,p_value=stats.f_oneway(dataset['etest_p'],dataset['mba_p'])

p_value
# Out:
# 4.672547689133573e-21

# %%
if p_value < 0.05:
    print("Reject H0 → Significant difference")
else:
    print("Fail to Reject H0 → No significant difference")
# Out:
# Reject H0 → Significant difference

# %% [markdown]
# # 8)Test the similarity between the degree_t(Sci&Tech) and specialisation( Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_ind
group1 = dataset[dataset['degree_t'] == 'Sci&Tech']['salary']
group2 = dataset[dataset['specialisation'] == 'Mkt&HR']['salary']

t_stat, p_value = ttest_ind(group1,group2)
p_value
# Out:
# 0.007897969943471179

# %%
if p_value < 0.05:
    print("Reject H0 → Significant difference")
else:
    print("Fail to Reject H0 → No significant difference")
# Out:
# Reject H0 → Significant difference

# %% [markdown]
# # 9)Convert the normal distribution to standard normal distribution for salary column

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

dataset['salary_std'] = scaler.fit_transform(dataset[['salary']])

print(dataset[['salary', 'salary_std']])
# Out:
#        salary  salary_std
# 0    270000.0    0.461711
# 1    200000.0    0.008404
# 2    250000.0    0.332195
# 3         0.0   -1.286761
# 4    425000.0    1.465463
# ..        ...         ...
# 210  400000.0    1.303568
# 211  275000.0    0.494090
# 212  295000.0    0.623607
# 213  204000.0    0.034307
# 214       0.0   -1.286761
#
# [215 rows x 2 columns]

# %%
std_dataset = dataset.drop('salary', axis=1)
std_dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 211  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 212  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 213  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 214  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary_std
# ...

# %% [markdown]
# # 10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
from scipy.stats import norm

# Mean and std of salary
mean = dataset['salary'].mean()
std = dataset['salary'].std()

# PDF values at 700000 and 900000
pdf_700k = norm.pdf(700000, mean, std)
pdf_900k = norm.pdf(900000, mean, std)

print("PDF at 700000:", pdf_700k)
print("PDF at 900000:", pdf_900k)

prob = norm.cdf(900000, mean, std) - norm.cdf(700000, mean, std)

print("Probability between 700k and 900k:", prob)
# Out:
# PDF at 700000: 1.3596204396845918e-08
# PDF at 900000: 8.98163035735494e-11
# Probability between 700k and 900k: 0.0005973243061798694

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


x = np.linspace(dataset['salary'].min(), dataset['salary'].max(), 1000)
y = norm.pdf(x, mean, std)

plt.plot(x, y)

# Highlight area (make it visible)
x_fill = np.linspace(700000, 900000, 200)
y_fill = norm.pdf(x_fill, mean, std)

plt.fill_between(x_fill, y_fill, alpha=0.5)  # transparency added

# Add vertical lines for clarity
plt.axvline(700000)
plt.axvline(900000)

# Probability text
prob = norm.cdf(900000, mean, std) - norm.cdf(700000, mean, std)
plt.text(700000, max(y)*0.3, f"Prob ≈ {prob:.6f}")

plt.title("Salary Distribution with Highlighted Range")
plt.xlabel("Salary")
plt.ylabel("Density")

plt.show()

# %% [markdown]
# # 11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_rel
etest_t = dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
mba_t = dataset[dataset['degree_t']=='Sci&Tech']['mba_p']

ttest_rel(etest_t,mba_t)
# Out:
# Ttest_relResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06)

# %%
if p2 < 0.05:
    print("Reject Null Hypothesis & Accept Alt Hypothesis")
else:
    print("Accept Null Hypothesis & Reject Alt Hypothesis")
# Out:
# Accept Null Hypothesis & Reject Alt Hypothesis

# %% [markdown]
# # 12)Which parameter is highly correlated with salary?

# %%
std_dataset.corr()
# Out:
#                sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p  \
# sl_no       1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327
# ssc_p      -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478
# hsc_p      -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823
# degree_p   -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364
# etest_p     0.063636  0.261993  0.245113  0.224470  1.000000  0.218055
# mba_p       0.022327  0.388478  0.354823  0.402364  0.218055  1.000000
# salary_std  0.002543  0.538090  0.452569  0.408371  0.186988  0.139823
#
#             salary_std
# sl_no         0.002543
# ssc_p         0.538090
# hsc_p         0.452569
# degree_p      0.408371
# etest_p       0.186988
# mba_p         0.139823
# salary_std    1.000000

# %%
corr = std_dataset.corr()['salary_std']
print(corr.sort_values(ascending=False))
# Out:
# salary_std    1.000000
# ssc_p         0.538090
# hsc_p         0.452569
# degree_p      0.408371
# etest_p       0.186988
# mba_p         0.139823
# sl_no         0.002543
# Name: salary_std, dtype: float64

# %%
#ssc_p-0.538090 is moderately correlated to salary compared to others

# %%
import matplotlib.pyplot as plt

# Scatter plot
plt.scatter(dataset['ssc_p'], dataset['salary'])

plt.xlabel("ssc_p(ssc_p)")
plt.ylabel("Salary")
plt.title("Salary vs ssc_p")

plt.show()

# %%
#The scatter plot shows a moderate positive correlation between ssc_p and salary.
